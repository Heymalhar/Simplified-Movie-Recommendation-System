# %%
from model import make_recommendations
import pandas as pd

# %%
data = pd.read_csv('data2.csv')

data
# Out:
#     movieId                               title  ... ratings  director
# 0         1                    Toy Story (1995)  ...     4.5    malhar
# 1         2                      Jumanji (1995)  ...     4.0    pandya
# 2         3             Grumpier Old Men (1995)  ...     3.8    malhar
# 3         4            Waiting to Exhale (1995)  ...     4.2    pandya
# 4         5  Father of the Bride Part II (1995)  ...     3.5    family
# 5         6                         Heat (1995)  ...     4.7    malhar
# 6         7                      Sabrina (1995)  ...     4.3    family
# 7         8                 Tom and Huck (1995)  ...     3.9    family
# 8         9                 Sudden Death (1995)  ...     4.6    malhar
# 9        10                    GoldenEye (1995)  ...     4.8    family
# 10       11       American President The (1995)  ...     4.4    family
# 11       12  Dracula: Dead and Loving It (1995)  ...     3.6    malhar
# ...

# %%
user_movie = "Toy Story (1995)"
num_recs = 14

# %%
recs = make_recommendations(user_movie, num_recs)

# %%
print(f"\nTop {num_recs} recommendations for '{user_movie}':")
for idx, (title, similarity) in enumerate(recs, start=1):
    print(f"{idx}. {title} (Similarity: {similarity})")
# Out:
# Top 14 recommendations for 'Toy Story (1995)':
# 1. Jumanji (1995) (Similarity: 0.6617750562882547)
# 2. Balto (1995) (Similarity: 0.6617750562882547)
# 3. Tom and Huck (1995) (Similarity: 0.5450727260418616)
# 4. Grumpier Old Men (1995) (Similarity: 0.5437672715897042)
# 5. Dracula: Dead and Loving It (1995) (Similarity: 0.5409683025054284)
# 6. Sudden Death (1995) (Similarity: 0.41519744283964843)
# 7. Father of the Bride Part II (1995) (Similarity: 0.3958351665371815)
# 8. Sabrina (1995) (Similarity: 0.3515341198700242)
# 9. GoldenEye (1995) (Similarity: 0.32197280798283434)
# 10. Heat (1995) (Similarity: 0.32010178667514244)
# 11. American President The (1995) (Similarity: 0.3142715363502019)
# 12. Waiting to Exhale (1995) (Similarity: 0.31020118464462076)
# 13. Sense and Sensibility (1995) (Similarity: 0.1590189842698528)
# 14. Casino (1995) (Similarity: 0.14757330935348795)
